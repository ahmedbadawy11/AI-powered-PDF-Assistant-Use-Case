# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedbadawy11/AI-powered-PDF-Assistant-Use-Case/blob/main/RAG_with_QA_before_fine_tune.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install chromadb
# !pip install langchain
# !pip install langchain_community
# !pip install transformers
# !pip install sentence-transformers
# !pip install bitsandbytes
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 4.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 3.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 21.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 kB 5.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.0/107.0 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 283.7/283.7 kB 38.1 MB/s eta 0:00:00
# ...

# %%
import torch
# Check if CUDA (GPU support) is available
if torch.cuda.is_available():
    # Get the current device
    device = torch.device('cuda')
    print(device)
    current_device = torch.cuda.current_device()
    num_gpus = torch.cuda.device_count()
    # Get the name of the GPU
    gpu_name = torch.cuda.get_device_name(current_device)
    print(num_gpus)

    print(f"PyTorch is using GPU: {gpu_name}")
else:
    # If CUDA is not available, use CPU
    device = torch.device('cpu')
    print("PyTorch is using CPU")
# Out:
# cuda
# 1
# PyTorch is using GPU: Tesla T4

# %%
# import os
# os.environ["HF_HUB_DISABLE_SYMLINKS_WARNING"] = "1"

# %%
from langchain_community.document_loaders.text import TextLoader

loader = TextLoader('all_text.txt')
all_text=loader.load()

# %%
all_text[0]
# Out:
# Document(metadata={'source': 'all_text.txt'}, page_content='مصرء أرض الأهرامات الشاهقة والعجائب القديمة» تتمتع ببيئة فريدة تشكلت من خلال التفاعل المعقد بين العوامل الحية\n(الحيوية) والعوامل غير الحية (اللاأحيائية). فهم هذه العوامل ضروري لتقدير التوازن البيئي الدقيق لمصر والتحديات التي\n.تواجهها\n\nأرض التناقضات: وفرة حيوية وجفاف\n\nعلى الرغم من المناخ الصحراوي القاسيء تدعم مصر مجموعة متنوعة من الحياة النباتية والحيوانية. تتكيف أشجار الأكاسيا\nبقدرتها على حفظ المياه مع الرمال الصحراويةء بينما تنمو نباتات البردي ونخيل التمر على طول نهر النيل الذي يمنح الحياة»\nمما يوفر الغذاء والمأوى لمجموعة متنوعة من الحيوانات. هذه النظم البيئية النابضة بالحياة تظهر مرونة الحياة الرائعة في\n.مصر\n\nنهر النيل: شريان الحياة لمصر\n\nنهر النيل هو قلب النظام البيئي لمصرء شريان حيوي حافظ على السكان والزراعة لآلاف السنين. كانت فيضاناته السنوية تودع\nالطمي الخصيب. مما يخلق دلتا النيل» وهي منطقة زراعية حيوية. هذه الشريط الخصيب من الأرض وسط الصحراء الشاسعة\nيبرز أهمية النيل للحياة في مصر. ومع ذلك. فإن بناء السد
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    # Set a really small chunk size, just to show.
    chunk_size=400,
    chunk_overlap=20,
    length_function=len,
    # is_separator_regex=False,
)

# %%
query_1="Enviromental_factors_egypt_arabic"
meta_data={"document":query_1}

# %%
chunks = text_splitter.create_documents([all_text[0].page_content],metadatas=[meta_data])

# %%
chunks[0]
# Out:
# Document(metadata={'document': 'Enviromental_factors_egypt_arabic'}, page_content='مصرء أرض الأهرامات الشاهقة والعجائب القديمة» تتمتع ببيئة فريدة تشكلت من خلال التفاعل المعقد بين العوامل الحية\n(الحيوية) والعوامل غير الحية (اللاأحيائية). فهم هذه العوامل ضروري لتقدير التوازن البيئي الدقيق لمصر والتحديات التي\n.تواجهها\n\nأرض التناقضات: وفرة حيوية وجفاف')

# %%
from langchain.embeddings import SentenceTransformerEmbeddings

# %%
from langchain.embeddings import SentenceTransformerEmbeddings

model_path = "./paraphrase_multilingual_MiniLM_model"  # Path where you saved the model files
model_name = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
encode_kwargs = {'normalize_embeddings': True}
llm_embedding = SentenceTransformerEmbeddings(model_name=model_name,encode_kwargs=encode_kwargs)

# Now you can use llm_embedding for your tasks
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
from langchain.vectorstores import Chroma
# vector database
save_to_dir = "wiki_chroma_db_3"
docs_ids=list(range(len(chunks)))
docs_ids=[str(d) for d in docs_ids]
vector_db = Chroma.from_documents(
    chunks,
    llm_embedding,
    persist_directory=save_to_dir,
    ids=docs_ids
)

# %%
# !pip install accelerate
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.1/314.1 kB 5.3 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModel
from transformers import AutoModelForCausalLM, AutoTokenizer
from transformers.utils.quantization_config import BitsAndBytesConfig

llm_name="Qwen/Qwen2-7B-Instruct"
quantization_config = BitsAndBytesConfig(
    load_in_4bit=True,
    load_in_8bit=False,
)
Qwen_model = AutoModelForCausalLM.from_pretrained(
    llm_name,
    quantization_config=quantization_config,
    torch_dtype="auto",
    device_map="auto"
)
Qwen_tokenizer = AutoTokenizer.from_pretrained(llm_name)
# Out:
# config.json:   0%|          | 0.00/663 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/27.8k [00:00<?, ?B/s]
# ...
# model-00001-of-00004.safetensors:   0%|          | 0.00/3.95G [00:00<?, ?B/s]
# model-00002-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00003-of-00004.safetensors:   0%|          | 0.00/3.86G [00:00<?, ?B/s]
# model-00004-of-00004.safetensors:   0%|          | 0.00/3.56G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/243 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# # Define the directory to save the model and tokenizer
# save_directory = "./Qwen2-1.5B"

# # Save the tokenizer and model to the specified directory
# Qwen_tokenizer.save_pretrained(save_directory)
# Qwen_model.save_pretrained(save_directory)
# Out:
# c:\Users\ahmed\anaconda3\envs\ai-assistant\lib\site-packages\transformers\modeling_utils.py:2525: UserWarning: Attempting to save a model with offloaded modules. Ensure that unallocated cpu memory exceeds the `shard_size` (5GB default)
#   warnings.warn(

# %%
from langchain.prompts import PromptTemplate
from langchain.chains.question_answering import load_qa_chain

# %%
qna_template = "\n".join([
   "أجب عن السؤال التالي باللغة العربية باستخدام السياق المقدم",
    "إذا لم تكن الإجابة واردة في السياق، فقل'لا توجد إجابة متاحة'",
    "### Context:",
    "{context}",
    "",
    "### Question:",
    "{question}",
    "",
    "### Answer:",
])


qna_prompt=PromptTemplate(
    template=qna_template,
    input_variables=["context","question"],
    # verbose=True
)

# %%
question = "ما هي التحديات البيئية التي تواجه مصر؟"
query_text = "In which year did Tesla's fathre die?"


similar_docs=vector_db.similarity_search(question,k=4)

# %%
similar_docs[3]
# Out:
# Document(metadata={'document': 'Enviromental_factors_egypt_arabic'}, page_content='يلقي شبح تغير المناخ بظلاله الطويلة على بيئة مصرء مهدذدا باضطراب التوازن الدقيق الذي يدعم الحياة في هذا البلد الرائع.\nبدأت درجات الحرارة العالمية المرتفعة» وهي سمة بارزة لتغير المناخ» في التأثير الواضح. ترسم التوقعات لمصر صورة\nمثيرة للقلق» حيث تشير التقديرات إلى زيادة تتراوح بين 2 درجة مئوية إلى 4 درجة مئوية (3.6 درجة فهرنهايت إلى 7.2\n.درجة فهرنهايت) بحلول نهاية القرن الحادي والعشرين')

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering, pipeline
from langchain import HuggingFacePipeline
# Create a QA pipeline
qa_pipeline = pipeline("text-generation", model=Qwen_model , tokenizer=Qwen_tokenizer,max_new_tokens=500 )

# Integrate with langchain
hf_pipeline = HuggingFacePipeline(pipeline=qa_pipeline)

# %%
# print (hf_pipeline.invoke("ما هي عاصمة مصر"))

# %%
stuff_chain = load_qa_chain(hf_pipeline, chain_type="stuff", prompt=qna_prompt)

# %%
answer=stuff_chain(
    {
        "input_documents":similar_docs,
        "question": question
    },
     return_only_outputs=True,

)
print(answer["output_text"])
# Out:
# أجب عن السؤال التالي باللغة العربية باستخدام السياق المقدم
# إذا لم تكن الإجابة واردة في السياق، فقل'لا توجد إجابة متاحة'
# ### Context:
# مصرء أرض الأهرامات الشاهقة والعجائب القديمة» تتمتع ببيئة فريدة تشكلت من خلال التفاعل المعقد بين العوامل الحية
# (الحيوية) والعوامل غير الحية (اللاأحيائية). فهم هذه العوامل ضروري لتقدير التوازن البيئي الدقيق لمصر والتحديات التي
# .تواجهها
#
# أرض التناقضات: وفرة حيوية وجفاف
#
# على الرغم من المناخ الصحراوي القاسيء تدعم مصر مجموعة متنوعة من الحياة النباتية والحيوانية. تتكيف أشجار الأكاسيا
# بقدرتها على حفظ المياه مع الرمال الصحراويةء بينما تنمو نباتات البردي ونخيل التمر على طول نهر النيل الذي يمنح الحياة»
# مما يوفر الغذاء والمأوى لمجموعة متنوعة من الحيوانات. هذه النظم البيئية النابضة بالحياة تظهر مرونة الحياة الرائعة في
# .مصر
#
# نهر النيل: شريان الحياة لمصر
#
# نهر النيل هو قلب النظام البيئي لمصرء شريان حيوي حافظ على السكان والزراعة لآلاف السنين. كانت فيضاناته السنوية تودع
# ...
